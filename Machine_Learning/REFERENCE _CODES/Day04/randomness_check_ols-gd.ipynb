# %%
import numpy as np
from sklearn.linear_model import LinearRegression, SGDRegressor

import warnings
warnings.filterwarnings("ignore")

# %%
X = np.random.randint(0, 100, size=1000).astype(float).reshape((-1, 1))
y = X * 0.54 + 98.124

# %%
X.shape, y.shape
# Out:
# ((1000, 1), (1000, 1))

# %%
results = []
for i in range(50):
    lr = LinearRegression()
    lr_gd = SGDRegressor(max_iter=1000, learning_rate="adaptive")
    lr.fit(X, y), lr_gd.fit(X, y)
    print(f"{i}: lr: {lr.coef_[0], lr.intercept_[0]} - lr_gd: {lr_gd.coef_[0], lr_gd.intercept_[0]}")
    results.append(f"{i}: lr: {lr.coef_[0], lr.intercept_[0]} - lr_gd: {lr_gd.coef_[0], lr_gd.intercept_[0]}")
# Out:
# 0: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5351929337948463, 98.43919449359551)
# 1: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.6483798408842377, 90.65629739267504)
# 2: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5450252433079684, 97.79808903317284)
# 3: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.558295211999768, 96.72912683407516)
# 4: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5447211424797692, 97.81703201510038)
# 5: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5516546595634265, 97.42400177245536)
# 6: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5536333465015658, 97.15115889242983)
# 7: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5937780747794208, 95.20641000086268)
# 8: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.6515877978390652, 90.33760921969346)
# 9: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5445521516652768, 97.82727500396858)
# 10: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5258362941292241, 98.89350416109366)
# 11: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5446738414369275, 97.81822368838755)
# 12: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5530278448508905, 97.13766411114315)
# 13: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5352189479104515, 98.43176883727365)
# 14: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5351252194043309, 98.44211031008618)
# 15: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5763442085547847, 94.93622167200365)
# 16: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5352597279341881, 98.43255275848699)
# 17: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5762663468035515, 96.10048739515274)
# 18: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5446731979786149, 97.81968188212781)
# 19: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5820785552071707, 95.90601072639923)
# 20: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5448061616195418, 97.81267565737437)
# 21: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.6094087901750195, 93.04128382517825)
# 22: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.4589931624938081, 104.59882187670763)
# 23: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5118191091239772, 99.70111491831635)
# 24: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5237779692763068, 99.05744138677755)
# 25: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.29658244667009115, 113.1913533946701)
# 26: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5453122814309688, 97.77634092053823)
# 27: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5349067629418762, 98.45478976204578)
# 28: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.3746546120619457, 109.53207101601046)
# 29: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5255185758539264, 99.49249303162922)
# 30: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.6130443135051237, 94.49620231939647)
# 31: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5153887656979307, 99.61485338119988)
# 32: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.6246794988157389, 93.16986968645513)
# 33: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5449677362666544, 97.80179510200283)
# 34: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.6631627605422777, 90.30212285378738)
# 35: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.569388646353911, 96.30666935443645)
# 36: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.6000848213291664, 93.32839471458794)
# 37: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5448293657574393, 97.81049500160417)
# 38: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5324334021490509, 98.78070161220941)
# 39: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5230109818269703, 99.02212139588701)
# 40: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.4720391507347461, 103.82557232007406)
# 41: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5159579372485116, 99.6277191193146)
# 42: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5543118085293536, 97.25829608851838)
# 43: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5630549299322706, 96.40261058200029)
# 44: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5624072661383402, 96.5087219046473)
# 45: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5673249246791484, 96.41675506311192)
# 46: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5446074240872554, 97.82317890428273)
# 47: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.4955634065354207, 101.47481660523023)
# 48: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5187697964890479, 99.8346135383563)
# 49: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5353165096400485, 98.43112211987324)

# %%
results[:10], results[-10:]
# Out:
# (['0: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5351929337948463, 98.43919449359551)',
#   '1: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.6483798408842377, 90.65629739267504)',
#   '2: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5450252433079684, 97.79808903317284)',
#   '3: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.558295211999768, 96.72912683407516)',
#   '4: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5447211424797692, 97.81703201510038)',
#   '5: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5516546595634265, 97.42400177245536)',
#   '6: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5536333465015658, 97.15115889242983)',
#   '7: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5937780747794208, 95.20641000086268)',
#   '8: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.6515877978390652, 90.33760921969346)',
#   '9: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5445521516652768, 97.82727500396858)'],
#  ['40: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.4720391507347461, 103.82557232007406)',
#   '41: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5159579372485116, 99.6277191193146)',
#   '42: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5543118085293536, 97.25829608851838)',
#   '43: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5630549299322706, 96.40261058200029)',
#   '44: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5624072661383402, 96.5087219046473)',
#   '45: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5673249246791484, 96.41675506311192)',
#   '46: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5446074240872554, 97.82317890428273)',
#   '47: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.4955634065354207, 101.47481660523023)',
#   '48: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5187697964890479, 99.8346135383563)',
#   '49: lr: (array([0.54]), 98.12400000000002) - lr_gd: (0.5353165096400485, 98.43112211987324)'])
